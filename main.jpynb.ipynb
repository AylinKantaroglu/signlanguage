# %%
import pandas as pd

COLUMNS = ['x0', 'y0', 'z0', 'x1', 'y1', 'z1', 'x2', 'y2', 'z2', 'x3',
       'y3', 'z3', 'x4', 'y4', 'z4', 'x5', 'y5', 'z5', 'x6', 'y6', 'z6', 'x7',
       'y7', 'z7', 'x8', 'y8', 'z8', 'x9', 'y9', 'z9', 'x10', 'y10', 'z10',
       'x11', 'y11', 'z11', 'x12', 'y12', 'z12', 'x13', 'y13', 'z13', 'x14',
       'y14', 'z14', 'x15', 'y15', 'z15', 'x16', 'y16', 'z16', 'x17', 'y17',
       'z17', 'x18', 'y18', 'z18', 'x19', 'y19', 'z19', 'x20', 'y20', 'z20']

df = pd.read_csv('C:/Users/aylen/signlanguage/Arabic Sign Language Letters Dataset.csv',delimiter=',', encoding='ascii')
print("DAtensatzgröße: ", df.shape)
print(df.head()) # Erste Zeilen anzeigen
# Out:
# DAtensatzgröße:  (7137, 64)
#   letter        x0        y0            z0        x1        y1        z1  \
# 0    Ain  0.281848  0.770933  2.127359e-06  0.299459  0.581939  0.003215
# 1    Ain  0.153687  0.627563  2.449348e-06  0.212909  0.540727 -0.023421
# 2    Ain  0.025697  0.571254  2.139683e-06  0.117762  0.439931  0.017492
# 3    Ain  0.114419  0.846487  7.563933e-07  0.133112  0.608031  0.041805
# 4    Ain  0.297838  0.834262  9.990022e-07  0.329022  0.666287 -0.002941
#
#          x2        y2        z2  ...       z17       x18       y18       z18  \
# 0  0.407830  0.460463 -0.044538  ... -0.232573  0.612845  0.683520 -0.210898
# 1  0.318150  0.499655 -0.086765  ... -0.259077  0.424218  0.697448 -0.285401
# 2  0.267403  0.373269 -0.000136  ... -0.118686  0.410647  0.623118 -0.082564
# 3  0.228139  0.528467  0.111665  ...  0.169150  0.365031  0.768893  0.237965
# 4  0.363154  0.540206 -0.032642  ... -0.141643  0.415088  0.705962 -0.169957
#
# ...

# %%
df.describe()
# Out:
#                 x0           y0            z0           x1           y1  \
# count  7137.000000  7137.000000  7.137000e+03  7137.000000  7137.000000
# mean      0.467330     0.756036  2.238571e-07     0.516278     0.691799
# std       0.162783     0.143334  1.191918e-06     0.158857     0.131123
# min      -0.128424    -0.014049 -5.071185e-06    -0.083088     0.105294
# 25%       0.378743     0.673478 -7.131400e-07     0.412982     0.605782
# 50%       0.470101     0.775747  3.265766e-07     0.534244     0.706920
# 75%       0.553918     0.862242  1.089368e-06     0.628498     0.790821
# max       1.141863     1.073876  7.022083e-06     1.016284     0.997309
#
#                 z1           x2           y2           z2           x3  ...  \
# count  7137.000000  7137.000000  7137.000000  7137.000000  7137.000000  ...
# mean     -0.059118     0.543071     0.599932    -0.095455     0.549572  ...
# std       0.073518     0.178300     0.116039     0.100647     0.182262  ...
# ...

# %%
df['letter'].value_counts().to_frame()
# Out:
#              count
# letter
# Teh            278
# Sheen          274
# Beh            274
# Theh           271
# Al             269
# Seen           262
# Yeh            261
# Sad            261
# Alef           258
# Dad            256
# Lam            253
# Kaf            252
# Laa            240
# Meem           240
# Feh            236
# Teh_Marbuta    230
# Dal            219
# Ghain          216
# Noon           214
# Zah            210
# Ain            209
# Reh            206
# Heh            203
# Waw            201
# Tah            196
# Khah           196
# Qaf            193
# Jeem           192
# Zain           191
# thal           188
# Hah            188

# %%
# 1. Features (X): Alle Spalten außer der Label-Spalte
X = df.drop(columns=['letter']).values 

# 2. Labels (y): Nur die Label-Spalte
y = df['letter'].values

print("Shape von X (Koordinaten):", X.shape)
print("Shape von y (Labels):", y.shape)
# Out:
# Shape von X (Koordinaten): (7137, 63)
# Shape von y (Labels): (7137,)

# %%
from sklearn.manifold import TSNE

reducer = TSNE(random_state=2025, verbose=True, n_jobs=1, perplexity=20.0, init='pca')
df[['x', 'y']] = reducer.fit_transform(X=df[COLUMNS])
# Out:
# [t-SNE] Computing 61 nearest neighbors...
# [t-SNE] Indexed 7137 samples in 0.007s...
# [t-SNE] Computed neighbors for 7137 samples in 8.177s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 7137
# [t-SNE] Computed conditional probabilities for sample 2000 / 7137
# [t-SNE] Computed conditional probabilities for sample 3000 / 7137
# [t-SNE] Computed conditional probabilities for sample 4000 / 7137
# [t-SNE] Computed conditional probabilities for sample 5000 / 7137
# [t-SNE] Computed conditional probabilities for sample 6000 / 7137
# [t-SNE] Computed conditional probabilities for sample 7000 / 7137
# [t-SNE] Computed conditional probabilities for sample 7137 / 7137
# [t-SNE] Mean sigma: 0.223843
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 82.141426
# [t-SNE] KL divergence after 1000 iterations: 1.467814

# %%
import plotly.express as px

fig = px.scatter(
    df,
    x="x",
    y="y",
    color="letter",
    height=700,
    width=700
)

fig.update_traces(marker=dict(size=6))  # entspricht s=12 in seaborn (ungefähr)
fig.update_layout(
    legend=dict(
        x=1.05,
        y=0.5
    )
)

fig.show()

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical

# a) Buchstaben in Zahlen umwandeln (z.B. 'Alif' -> 0, 'Ba' -> 1)
label_encoder = LabelEncoder()
integer_encoded = label_encoder.fit_transform(y)
# Zeigt die Mapping an: z.B. (0: 'Alif', 1: 'Ba', ...)
print("Anzahl der Klassen:", len(label_encoder.classes_))

# b) Zahlen in One-Hot-Vektoren umwandeln (z.B. 0 -> [1, 0, 0, ...])
y_encoded = to_categorical(integer_encoded) 

NUM_CLASSES = y_encoded.shape[1]

# Train/Test-Split
X_train, X_val, y_train, y_val = train_test_split(
    X, y_encoded, test_size=0.2, random_state=42
)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# File c:\Users\aylen\signlanguage\venv\Lib\site-packages\tensorflow\python\pywrap_tensorflow.py:73
#      72 try:
# ---> 73   from tensorflow.python._pywrap_tensorflow_internal import *
#      74 # This try catch logic is because there is no bazel equivalent for py_extension.
#      75 # Externally in opensource we must enable exceptions to load the shared object
#      76 # by exposing the PyInit symbols with pybind. This error will only be
#      77 # caught internally or if someone changes the name of the target _pywrap_tensorflow_internal.
#      78
#      79 # This logic is used in other internal projects using py_extension.
#
# ImportError: DLL load failed while importing _pywrap_tensorflow_internal: Eine DLL-Initialisierungsroutine ist fehlgeschlagen.
#
# During handling of the above exception, another exception occurred:
#
# ...

# %%
from tensorflow.keras import layers, models

# Modell erstellen
dnn_model = models.Sequential([
    layers.Dense(128, activation='relu', input_shape=(X_train.shape[1],)),
    layers.Dense(64, activation='relu'),
    layers.Dense(y_categorical.shape[1], activation='softmax')
])

dnn_model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Training
history = dnn_model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=30, batch_size=32)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\tensorflow\python\pywrap_tensorflow.py:73
#      72 try:
# ---> 73   from tensorflow.python._pywrap_tensorflow_internal import *
#      74 # This try catch logic is because there is no bazel equivalent for py_extension.
#      75 # Externally in opensource we must enable exceptions to load the shared object
#      76 # by exposing the PyInit symbols with pybind. This error will only be
#      77 # caught internally or if someone changes the name of the target _pywrap_tensorflow_internal.
#      78
#      79 # This logic is used in other internal projects using py_extension.
#
# ...

# %%
import plotly.graph_objects as go

# Trainings- und Validierungsaccuracy
fig = go.Figure()
fig.add_trace(go.Scatter(y=history.history['accuracy'], mode='lines+markers', name='Train Accuracy'))
fig.add_trace(go.Scatter(y=history.history['val_accuracy'], mode='lines+markers', name='Validation Accuracy'))
fig.update_layout(title='DNN Training Accuracy', xaxis_title='Epoch', yaxis_title='Accuracy')
fig.show()

# Trainings- und Validierungsverlust
fig2 = go.Figure()
fig2.add_trace(go.Scatter(y=history.history['loss'], mode='lines+markers', name='Train Loss'))
fig2.add_trace(go.Scatter(y=history.history['val_loss'], mode='lines+markers', name='Validation Loss'))
fig2.update_layout(title='DNN Training Loss', xaxis_title='Epoch', yaxis_title='Loss')
fig2.show()

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, confusion_matrix
import plotly.figure_factory as ff

# Labels zurück zu integer für Random Forest
y_rf = y_encoded
X_train_rf, X_val_rf, y_train_rf, y_val_rf = train_test_split(X, y_rf, test_size=0.2, random_state=42)

rf_model = RandomForestClassifier(n_estimators=200, random_state=42)
rf_model.fit(X_train_rf, y_train_rf)

y_pred_rf = rf_model.predict(X_val_rf)
accuracy_rf = accuracy_score(y_val_rf, y_pred_rf)
print(f"Random Forest Accuracy: {accuracy_rf:.4f}")

cm = confusion_matrix(y_val_rf, y_pred_rf)
labels_list = le.classes_

fig_cm = ff.create_annotated_heatmap(
    z=cm,
    x=labels_list.tolist(),
    y=labels_list.tolist(),
    colorscale='Viridis',
    showscale=True
)

fig_cm.update_layout(title='Random Forest Confusion Matrix', xaxis_title='Predicted', yaxis_title='True')
fig_cm.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[44], line 7
#       3 import plotly.figure_factory as ff
#       5 # --- KORREKTUR 1: Verwende die Integer-kodierten Labels (y_integer) ---
#       6 # y_integer wurde in der Zelle 1 des Gesamtcodes erstellt.
# ----> 7 y_rf = y_integer # KEIN y_encoded!
#       9 # Führe die Aufteilung der Daten durch
#      10 # X ist das Feature-Set, y_rf (y_integer) ist das Target-Set
#      11 X_train_rf, X_val_rf, y_train_rf, y_val_rf = train_test_split(
#      12     X,
#      13     y_rf,
#    (...)
#      16     stratify=y_rf # Stratify mit Integer-Labels
#      17 )
#
# NameError: name 'y_integer' is not defined
